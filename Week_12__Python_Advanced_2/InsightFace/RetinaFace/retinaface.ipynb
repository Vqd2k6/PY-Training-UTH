# %%
import os
os.environ["TF_USE_LEGACY_KERAS"] = "1"

from retinaface import RetinaFace
_ = RetinaFace.build_model()

# %%
from retinaface import RetinaFace 
import cv2
import matplotlib.pyplot as plt 
import numpy as np

# %%
img_path = './data/img1.jpg'
img = cv2.imread(img_path)

# %%
obj = RetinaFace.detect_faces(img_path)

# %%
len(obj.keys())
# Out:
# 13

# %%
obj['face_1']
# Out:
# {'score': np.float64(0.9997425079345703),
#  'facial_area': [np.int64(651), np.int64(974), np.int64(781), np.int64(1131)],
#  'landmarks': {'right_eye': [np.float32(679.76843), np.float32(1040.0996)],
#   'left_eye': [np.float32(737.9723), np.float32(1034.7106)],
#   'nose': [np.float32(708.5052), np.float32(1069.4543)],
#   'mouth_right': [np.float32(692.9247), np.float32(1097.7618)],
#   'mouth_left': [np.float32(738.061), np.float32(1092.6565)]}}

# %%
for key in obj.keys():
    identity = obj[key]
    facial_area = identity['facial_area']
    cv2.rectangle(  img , (facial_area[2],facial_area[3]) , (facial_area[0],facial_area[1]), (255,255,255) , 3 )

# %%
plt.figure(figsize=(16,9))
plt.imshow(img[:,:,::-1])
plt.show()

# %% [markdown]
# ### ***Face reconation***

# %%
# !pip install deepface
# Out:
# ...
#   Using cached pandas-2.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (91 kB)
# ...
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 11.1 MB/s  0:00:00
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# ...
# Using cached pandas-2.3.3-cp313-cp313-macosx_11_0_arm64.whl (10.7 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [deepface]/15 [deepface]
# ...

# %%
from deepface import DeepFace

# %%
obj = DeepFace.verify(img1_path='./data/img2.jpg' , img2_path= './data/img3.jpg' , model_name= 'ArcFace', detector_backend= 'retinaface')
# Out:
# 25-11-12 02:11:20 - 🔗 arcface_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/arcface_weights.h5 to /Users/vqd2k6/.deepface/weights/arcface_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/arcface_weights.h5
# To: /Users/vqd2k6/.deepface/weights/arcface_weights.h5
# 100%|██████████| 137M/137M [00:02<00:00, 53.5MB/s]

# %%
obj
# Out:
# {'verified': True,
#  'distance': 0.384071,
#  'threshold': 0.68,
#  'confidence': 74.86,
#  'model': 'ArcFace',
#  'detector_backend': 'retinaface',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 116,
#    'y': 40,
#    'w': 87,
#    'h': 119,
#    'left_eye': (182, 86),
#    'right_eye': (142, 83),
#    'nose': (161, 108),
#    'mouth_left': (177, 127),
#    'mouth_right': (140, 125)},
#   'img2': {'x': 506,
#    'y': 258,
#    'w': 127,
#    'h': 146,
#    'left_eye': (601, 326),
#    'right_eye': (547, 306),
#    'nose': (561, 335),
#    'mouth_left': (574, 370),
#    'mouth_right': (528, 353)}},
#  'time': 11.16}

# %%
obj = DeepFace.verify(img1_path='./data/img4.jpg' , img2_path= './data/img3.jpg' , model_name= 'ArcFace', detector_backend= 'retinaface')
obj
# Out:
# {'verified': True,
#  'distance': 0.46535,
#  'threshold': 0.68,
#  'confidence': 64.9,
#  'model': 'ArcFace',
#  'detector_backend': 'retinaface',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 371,
#    'y': 64,
#    'w': 87,
#    'h': 120,
#    'left_eye': (438, 113),
#    'right_eye': (399, 116),
#    'nose': (422, 140),
#    'mouth_left': (437, 152),
#    'mouth_right': (402, 154)},
#   'img2': {'x': 506,
#    'y': 258,
#    'w': 127,
#    'h': 146,
#    'left_eye': (601, 326),
#    'right_eye': (547, 306),
#    'nose': (561, 335),
#    'mouth_left': (574, 370),
#    'mouth_right': (528, 353)}},
#  'time': 6.73}
