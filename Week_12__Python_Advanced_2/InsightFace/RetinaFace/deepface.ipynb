# %%
from retinaface import RetinaFace 
import cv2
import matplotlib.pyplot as plt 
import numpy as np
from deepface import DeepFace

# %%
img1_path = './data/img2.jpg'
img2_path = './data/img4.jpg'

# %%
resp = DeepFace.verify(img1_path=img1_path , img2_path=img2_path, model_name='Facenet')
resp
# Out:
# {'verified': True,
#  'distance': 0.191996,
#  'threshold': 0.4,
#  'confidence': 83.94,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 107,
#    'y': 42,
#    'w': 109,
#    'h': 109,
#    'left_eye': (180, 87),
#    'right_eye': (141, 84)},
#   'img2': {'x': 362,
#    'y': 67,
#    'w': 112,
#    'h': 112,
#    'left_eye': (436, 112),
#    'right_eye': (398, 114)}},
#  'time': 0.53}

# %%
resp = DeepFace.verify(img1_path=img1_path , img2_path=img2_path, model_name='VGG-Face')
resp
# Out:
# 25-11-12 03:04:46 - 🔗 vgg_face_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5 to /Users/vqd2k6/.deepface/weights/vgg_face_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: /Users/vqd2k6/.deepface/weights/vgg_face_weights.h5
# 100%|██████████| 580M/580M [00:09<00:00, 61.6MB/s]
# {'verified': True,
#  'distance': 0.358006,
#  'threshold': 0.68,
#  'confidence': 85.66,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 107,
#    'y': 42,
#    'w': 109,
#    'h': 109,
#    'left_eye': (180, 87),
#    'right_eye': (141, 84)},
#   'img2': {'x': 362,
#    'y': 67,
#    'w': 112,
#    'h': 112,
#    'left_eye': (436, 112),
#    'right_eye': (398, 114)}},
#  'time': 12.96}

# %%
resp = DeepFace.verify(img1_path=img1_path , img2_path=img2_path, model_name='ArcFace')
resp
# Out:
# {'verified': True,
#  'distance': 0.409268,
#  'threshold': 0.68,
#  'confidence': 71.77,
#  'model': 'ArcFace',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 107,
#    'y': 42,
#    'w': 109,
#    'h': 109,
#    'left_eye': (180, 87),
#    'right_eye': (141, 84)},
#   'img2': {'x': 362,
#    'y': 67,
#    'w': 112,
#    'h': 112,
#    'left_eye': (436, 112),
#    'right_eye': (398, 114)}},
#  'time': 1.9}

# %%
import pandas as pd

# %%
df = DeepFace.find(img_path="./data/img2.jpg" , db_path='./data/',model_name='VGG-Face')
df
# Out:
# 25-11-12 03:11:51 - Searching ./data/img2.jpg in 16 length datastore
# 25-11-12 03:11:51 - find function duration 0.5725629329681396 seconds
# [          identity                                      hash  target_x  \
#  0  ./data/img5.jpg  2876699dcb4152f5a8b4fa40fb7b0dea8d7c694c       176
#  1  ./data/img4.jpg  a9f50e6c3791b890e29f47c575d746ff5e1fbf70       362
#  2  ./data/img1.jpg  8cb2b418b9caecf7098a1b0d7fe5361721ebd1d4       979
#
#     target_y  target_w  target_h  threshold  source_x  source_y  source_w  \
#  0       211       146       146       0.68       107        42       109
#  1        67       112       112       0.68       107        42       109
#  2       983       143       143       0.68       107        42       109
#
#     source_h  distance  confidence
#  0       109  0.331059       88.35
#  1       109  0.352591       86.22
#  2       109  0.669193       51.71  ]

# %%
img2 = cv2.imread('./data/img2.jpg')
plt.imshow(img2[:,:,::-1])

# %%
obj = DeepFace.analyze(img_path='./data/img2.jpg')
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# 25-11-12 03:14:08 - 🔗 facial_expression_model_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5 to /Users/vqd2k6/.deepface/weights/facial_expression_model_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /Users/vqd2k6/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 15.0MB/s]
# Action: age:  25%|██▌       | 1/4 [00:01<00:04,  1.58s/it]
# 25-11-12 03:14:11 - 🔗 age_model_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5 to /Users/vqd2k6/.deepface/weights/age_model_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# ...

# %%
obj
# Out:
# [{'emotion': {'angry': np.float32(3.107631e-05),
#    'disgust': np.float32(2.0232446e-07),
#    'fear': np.float32(0.37716746),
#    'happy': np.float32(99.6142),
#    'sad': np.float32(0.0072160936),
#    'surprise': np.float32(3.1049705e-05),
#    'neutral': np.float32(0.0013594591)},
#   'dominant_emotion': 'happy',
#   'region': {'x': 107,
#    'y': 42,
#    'w': 109,
#    'h': 109,
#    'left_eye': (180, 87),
#    'right_eye': (141, 84)},
#   'face_confidence': 0.9,
#   'age': 23,
#   'gender': {'Woman': np.float32(0.036522668), 'Man': np.float32(99.96347)},
#   'dominant_gender': 'Man',
#   'race': {'asian': np.float32(99.50152),
#    'indian': np.float32(0.052698728),
#    'black': np.float32(0.0003856106),
#    'white': np.float32(0.022835016),
#    'middle eastern': np.float32(2.7925358e-05),
#    'latino hispanic': np.float32(0.42253911)},
#   'dominant_race': 'asian'}]
